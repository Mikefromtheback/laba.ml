# %% [markdown]
# 1.

# %%
import pandas as pd
import numpy as np
# Out:
# /tmp/ipykernel_27295/2162656668.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('../data/marketing_campaign.csv', sep=';', index_col=0)
df
# Out:
#        Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# ID
# 5524         1957  Graduation         Single  58138.0        0         0
# 2174         1954  Graduation         Single  46344.0        1         1
# 4141         1965  Graduation       Together  71613.0        0         0
# 6182         1984  Graduation       Together  26646.0        1         0
# 5324         1981         PhD        Married  58293.0        1         0
# ...           ...         ...            ...      ...      ...       ...
# 10870        1967  Graduation        Married  61223.0        0         1
# 4001         1946         PhD       Together  64014.0        2         1
# 7270         1981  Graduation       Divorced  56981.0        0         0
# 8235         1956      Master       Together  69245.0        0         1
# 9405         1954         PhD        Married  52869.0        1         1
#
#       Dt_Customer  Recency  MntWines  MntFruits  ...  NumWebVisitsMonth  \
# ...

# %% [markdown]
# Количество жалоб

# %%
complains = sum(df['Complain'])
print(complains)
# Out:
# 21

# %% [markdown]
# Средний возраст всех

# %%
mid_age1 = np.mean(2024-df['Year_Birth'])
print(mid_age1)
# Out:
# 55.19419642857143

# %% [markdown]
# Средний возраст покупателей

# %%
df2 = df[df['MntWines'] + df['MntFruits'] + df['MntFishProducts'] + df['MntMeatProducts'] + df['MntSweetProducts'] + df['MntGoldProds'] > 0]
mid_age2 = np.mean(2024-df2['Year_Birth'])
print(mid_age2)
# Out:
# 55.19419642857143

# %% [markdown]
# То бишь одинаково

# %% [markdown]
# 2.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_style("whitegrid")
sns.barplot(data=df, x="Education", y="Income")
# Out:
# <Axes: xlabel='Education', ylabel='Income'>

# %% [markdown]
# вывод: базовое образование - низкий доход

# %%
sns.set_style("whitegrid")
sns.barplot(data=df, x="Education", y="Kidhome")
# Out:
# <Axes: xlabel='Education', ylabel='Kidhome'>

# %% [markdown]
# вывод: базовое образование - много детей в семье

# %%
sns.set_style("whitegrid")
sns.barplot(data=df, x="Education", y="Kidhome")
# Out:
# <Axes: xlabel='Education', ylabel='Kidhome'>

# %% [markdown]
# вывод: базовое образование - мало подростков в семье

# %%
sns.set_style("whitegrid")
sns.barplot(data=df, x="Education", y="NumWebPurchases")
# Out:
# <Axes: xlabel='Education', ylabel='NumWebPurchases'>

# %%
sns.set_style("whitegrid")
sns.barplot(data=df, x="Education", y="NumStorePurchases")
# Out:
# <Axes: xlabel='Education', ylabel='NumStorePurchases'>

# %% [markdown]
# вывод: базовое образование - мало покупок

# %%
sns.set_style("whitegrid")
sns.barplot(data=df, x="Kidhome", y="Income")
# Out:
# <Axes: xlabel='Kidhome', ylabel='Income'>

# %% [markdown]
# вывод: нет детей - высокий доход

# %%
sns.set_style("whitegrid")
sns.barplot(data=df, x="Kidhome", y="NumWebPurchases")
# Out:
# <Axes: xlabel='Kidhome', ylabel='NumWebPurchases'>

# %%
sns.set_style("whitegrid")
sns.barplot(data=df, x="Kidhome", y="NumStorePurchases")
# Out:
# <Axes: xlabel='Kidhome', ylabel='NumStorePurchases'>

# %% [markdown]
# вывод: есть дети - меньше покупок

# %%
sns.set_style("whitegrid")
sns.barplot(data=df, x="NumWebPurchases", y="NumStorePurchases")
# Out:
# <Axes: xlabel='NumWebPurchases', ylabel='NumStorePurchases'>

# %% [markdown]
# вывод: больше онлайн покупок - больше офлайн покупок
